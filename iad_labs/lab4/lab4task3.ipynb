# %% [markdown]
# Полиномиальная регрессия

# %%
# %pip install numpy scikit-learn matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\anmrt\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt

# %%
#Задание 1
X = np.arange(6).reshape(3, 2)
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %%
model = linear_model.LinearRegression()
model.fit(X_poly, np.array([3, 2, 1]))
# Out:
# LinearRegression()

# %%
X_test = np.linspace(0, 5, 100).reshape(50, 2)
X_test_poly = poly.transform(X_test)
y_pred = model.predict(X_test_poly)

# %%
plt.scatter(X[:, 0], [3, 2, 1], color='red', label='Исходные данные')
plt.plot(X_test[:, 0], y_pred, label='Полиномиальная регрессия')
plt.legend()
plt.show()

# %%
#Задание 2
x = np.arange(5)
y = 3 - 2*x + x**2 - x**3

# %%
pipeline = Pipeline([
    ('poly', PolynomialFeatures(degree=3)),
    ('linear', linear_model.LinearRegression())
])

# %%
pipeline.fit(x[:, np.newaxis], y)

coef = pipeline.named_steps['linear'].coef_
print("Коэффициенты полинома:", coef)
# Out:
# Коэффициенты полинома: [ 0. -2.  1. -1.]
